# %%
import pymysql
conn = pymysql.connect(host='localhost',port=3306,db='lolgamequiz',user='root',passwd='root',charset='utf8')
def sele(sql):
    cur = conn.cursor()
    cur.execute(sql)
    result = list(cur.fetchall())
    result = [list(r) for r in result]
    conn.commit()
    cur.close()
    
    return result

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
sql = 'select date, teamA, teamB, scoreA, scoreB, fullTeamA, fullTeamB from world2019'
data = sele(sql)
results = pd.DataFrame(data, columns=['date', 'teamA', 'teamB', 'scoreA', 'scoreB', 'fullTeamA', 'fullTeamB'])
print(results)

sql = 'select teamName, rank, region from rank2019'
data = sele(sql)
rank2019 = pd.DataFrame(data, columns=['teamName', 'rank', 'region'])
print(rank2019)
# Out:
#           date teamA teamB scoreA scoreB           fullTeamA  \
# 0   2019-10-02    CG   UOL      0      1       Clutch Gaming
# 1   2019-10-02   DFM   SPY      0      1  DetonatioN FocusMe
# 2   2019-10-02   MMM   UOL      1      0             MAMMOTH
# 3   2019-10-02   DFM   ISG      0      1  DetonatioN FocusMe
# 4   2019-10-02   MMM    CG      0      1             MAMMOTH
# ..         ...   ...   ...    ...    ...                 ...
# 83  2019-10-27   SKT   SPY      3      1       SK Telecom T1
# 84  2019-10-27   DWG    G2      1      3       DAMWON Gaming
# 85  2019-11-02    iG   FPX      1      3     Invictus Gaming
# 86  2019-11-03    G2   SKT      3      1          G2 Esports
# 87  2019-11-10    G2   FPX      0      3          G2 Esports
#
#                fullTeamB
# 0   Unicorns Of Love.CIS
# 1                 Splyce
# 2   Unicorns Of Love.CIS
# 3                 Isurus
# 4          Clutch Gaming
# ..                   ...
# 83                Splyce
# 84            G2 Esports
# 85       FunPlus Phoenix
# 86         SK Telecom T1
# 87       FunPlus Phoenix
#
# [88 rows x 7 columns]
#                  teamName rank region
# 0             Team Liquid    1    LCS
# 1                  Cloud9    2    LCS
# 2           Clutch Gaming    3    LCS
# 3            Team SoloMid    4    LCS
# 4    Counter Logic Gaming    5    LCS
# 5                FlyQuest    6    LCS
# 6            OpTic Gaming    7    LCS
# 7                Echo Fox    8    LCS
# 8        Golden Guardians    9    LCS
# 9             100 Thieves   10    LCS
# 10          SK Telecom T1    1    LCK
# 11                Griffin    2    LCK
# 12          DAMWON Gaming    3    LCK
# 13         SANDBOX Gaming    4    LCK
# 14       Kingzone DragonX    5    LCK
# 15             G2 Esports    1    LEC
# 16        FunPlus Phoenix    1    LPL
# 17                 J Team    1    LMS
# 18         Afreeca Freecs    6    LCK
# 19                  Gen.G    7    LCK
# 20             KT Rolster    8    LCK
# 21                 Fnatic    2    LEC
# 22                 Splyce    3    LEC
# 23    Royal Never Give Up    2    LPL
# 24        Invictus Gaming    3    LPL
# 25       Ahq eSports Club    2    LMS
# 26    Hanwha Life Esports    9    LCK
# 27    Jin Air Green Wings   10    LCK
# 28  FC Schalke 04 Esports    4    LEC
# 29                 Origen    5    LEC
# 30            Top Esports    4    LPL
# 31     Hong Kong Attitude    3    LMS
# 32  Rogue (European Team)    6    LEC
# 33              JD Gaming    5    LPL
# 34               MAD Team    4    LMS
# 35          Team Vitality    7    LEC
# 36        Bilibili Gaming    6    LPL
# 37          EDward Gaming    7    LPL
# 38           Flash Wolves    5    LMS
# 39              SK Gaming    8    LEC
# 40            LNG Esports    8    LPL
# 41        Dominus Esports    9    LPL
# 42                  G-Rex    6    LMS
# 43         Misfits Gaming    9    LEC
# 44          Excel Esports   10    LEC
# 45             LGD Gaming   10    LPL
# 46              Oh My God   11    LPL
# 47          Alpha Esports    7    LMS
# 48         Rogue Warriors   12    LPL
# 49       Dragon Gate Team    8    LMS
# 50                 Suning   13    LPL
# 51                Team WE   14    LPL
# 52            Vici Gaming   15    LPL
# 53           Victory Five   16    LPL

# %%
# clean data
# cover data type
results = results.astype({'date':'datetime64', 'teamA':'string', 'teamB':'string', 'scoreA':'int64', 'scoreB':'int64'})
# fix team name
results['teamA'] = results['teamA'].apply(lambda x: x.upper())
results['teamB'] = results['teamB'].apply(lambda x: x.upper())

# sort
results = results.sort_values(by='date')
results = results.reset_index()
results = results.drop(['index'], axis=1)
results

####################
# rank2019
# region
rank2019['region'] = rank2019['region'].apply(lambda x:x.split('_')[-1])
# rank
rank2019 = rank2019.astype({'rank':'int64'})
#results = results.merge(rank2019, how='left', left_on='fullTeamA', right_on='teamName')
rank2019
# Out:
#                  teamName  rank region
# 0             Team Liquid     1    LCS
# 1                  Cloud9     2    LCS
# 2           Clutch Gaming     3    LCS
# 3            Team SoloMid     4    LCS
# 4    Counter Logic Gaming     5    LCS
# 5                FlyQuest     6    LCS
# 6            OpTic Gaming     7    LCS
# 7                Echo Fox     8    LCS
# 8        Golden Guardians     9    LCS
# 9             100 Thieves    10    LCS
# 10          SK Telecom T1     1    LCK
# 11                Griffin     2    LCK
# 12          DAMWON Gaming     3    LCK
# 13         SANDBOX Gaming     4    LCK
# 14       Kingzone DragonX     5    LCK
# 15             G2 Esports     1    LEC
# 16        FunPlus Phoenix     1    LPL
# 17                 J Team     1    LMS
# 18         Afreeca Freecs     6    LCK
# 19                  Gen.G     7    LCK
# 20             KT Rolster     8    LCK
# 21                 Fnatic     2    LEC
# 22                 Splyce     3    LEC
# 23    Royal Never Give Up     2    LPL
# 24        Invictus Gaming     3    LPL
# 25       Ahq eSports Club     2    LMS
# 26    Hanwha Life Esports     9    LCK
# 27    Jin Air Green Wings    10    LCK
# 28  FC Schalke 04 Esports     4    LEC
# 29                 Origen     5    LEC
# 30            Top Esports     4    LPL
# 31     Hong Kong Attitude     3    LMS
# 32  Rogue (European Team)     6    LEC
# 33              JD Gaming     5    LPL
# 34               MAD Team     4    LMS
# 35          Team Vitality     7    LEC
# 36        Bilibili Gaming     6    LPL
# 37          EDward Gaming     7    LPL
# 38           Flash Wolves     5    LMS
# 39              SK Gaming     8    LEC
# 40            LNG Esports     8    LPL
# 41        Dominus Esports     9    LPL
# 42                  G-Rex     6    LMS
# 43         Misfits Gaming     9    LEC
# 44          Excel Esports    10    LEC
# 45             LGD Gaming    10    LPL
# 46              Oh My God    11    LPL
# 47          Alpha Esports     7    LMS
# 48         Rogue Warriors    12    LPL
# 49       Dragon Gate Team     8    LMS
# 50                 Suning    13    LPL
# 51                Team WE    14    LPL
# 52            Vici Gaming    15    LPL
# 53           Victory Five    16    LPL

# %%
df = results['scoreA'].append(results['scoreB'])
df = pd.DataFrame(df)
df.columns = ['score']
gy = df['score'].groupby(df['score'])
print(gy.count())
print(results[results['scoreA']==results['scoreB']])
# Out:
# score
# 0    79
# 1    85
# 2     1
# 3    11
# Name: score, dtype: int64
# Empty DataFrame
# Columns: [date, teamA, teamB, scoreA, scoreB, fullTeamA, fullTeamB]
# Index: []

# %%
# won
results['Awon'] = False
results['Bwon'] = False
results['Awon'] = results['scoreA']>results['scoreB']
results['Bwon'] = results['scoreA']<results['scoreB']
results
# Out:
#          date teamA teamB  scoreA  scoreB           fullTeamA  \
# 0  2019-10-02    CG   UOL       0       1       Clutch Gaming
# 1  2019-10-02   DFM   SPY       0       1  DetonatioN FocusMe
# 2  2019-10-02   MMM   UOL       1       0             MAMMOTH
# 3  2019-10-02   DFM   ISG       0       1  DetonatioN FocusMe
# 4  2019-10-02   MMM    CG       0       1             MAMMOTH
# ..        ...   ...   ...     ...     ...                 ...
# 83 2019-10-27   SKT   SPY       3       1       SK Telecom T1
# 84 2019-10-27   DWG    G2       1       3       DAMWON Gaming
# 85 2019-11-02    IG   FPX       1       3     Invictus Gaming
# 86 2019-11-03    G2   SKT       3       1          G2 Esports
# 87 2019-11-10    G2   FPX       0       3          G2 Esports
#
#                fullTeamB   Awon   Bwon
# 0   Unicorns Of Love.CIS  False   True
# 1                 Splyce  False   True
# 2   Unicorns Of Love.CIS   True  False
# 3                 Isurus  False   True
# 4          Clutch Gaming  False   True
# ..                   ...    ...    ...
# 83                Splyce   True  False
# 84            G2 Esports  False   True
# 85       FunPlus Phoenix  False   True
# 86         SK Telecom T1   True  False
# 87       FunPlus Phoenix  False   True
#
# [88 rows x 9 columns]

# %%
############################################
# region
results['regionA'] = None
results['regionB'] = None
results['AisLCK'] = False
results['AisLCS'] = False
results['AisLPL'] = False
results['AisLMS'] = False
results['BisLCK'] = False
results['BisLCS'] = False
results['BisLPL'] = False
results['BisLMS'] = False
for index, row in results.iterrows():
    teamA = row['fullTeamA']
    teamB = row['fullTeamB']
    regionA = rank2019[rank2019['teamName']==teamA]
    if not regionA.empty:
        regionA = regionA['region'].values[0]
        results.loc[index,'regionA'] = regionA
        if regionA == 'LCK':
            results.loc[index,'AisLCK'] = True
        elif regionA == 'LCS':
            results.loc[index,'AisLCS'] = True
        elif regionA == 'LPL':
            results.loc[index,'AisLPL'] = True
        elif regionA == 'LMS':
            results.loc[index,'AisLMS'] = True
    
    regionB = rank2019[rank2019['teamName']==teamB]
    if not regionB.empty:
        regionB = regionB['region'].values[0]
        results.loc[index,'regionB'] = regionB
        if regionB == 'LCK':
            results.loc[index,'BisLCK'] = True
        elif regionB == 'LCS':
            results.loc[index,'BisLCS'] = True
        elif regionB == 'LPL':
            results.loc[index,'BisLPL'] = True
        elif regionB == 'LMS':
            results.loc[index,'BisLMS'] = True

############################################
# rank
results['rankA'] = 5
results['rankB'] = 5
results['Ahigh'] = False
results['Bhigh'] = False
for index, row in results.iterrows():
    teamA = row['fullTeamA']
    teamB = row['fullTeamB']
    rankA = rank2019[rank2019['teamName']==teamA]
    if not rankA.empty:
        rankA = rankA['rank'].values[0]
    else:
        rankA = 5

    rankB = rank2019[rank2019['teamName']==teamB]
    if not rankB.empty:
        rankB = rankB['rank'].values[0]
    else:
        rankB = 5
    
    if rankA < rankB:
        results.loc[index,'Ahigh'] = True
    if rankB < rankA:
        results.loc[index,'Bhigh'] = True
        
    results.loc[index,'rankA'] = rankA
    results.loc[index,'rankB'] = rankB
    

##################################
# last won
results['Alastwon'] = False
results['Blastwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        won_last[teamA] = row['Awon']
        won_last[teamB] = row['Bwon']
        continue
    #ow['Alastwon'] = won_last[teamA]
    #ow['Blastwon'] = won_last[teamB]
    results.loc[index, 'Alastwon'] = won_last[teamA]
    results.loc[index, 'Blastwon'] = won_last[teamB]
    won_last[teamA] = row['Awon']
    won_last[teamB] = row['Bwon']

##################################
# last who won
results['lastAwon'] = False
results['BlastBwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        continue
    for index1, row1 in results[:index].iterrows():
        if row1['teamA'] == teamA and row1['teamB'] == teamB:
            
    
    results.loc[index, 'Alastwon'] = won_last[teamA]
    results.loc[index, 'Blastwon'] = won_last[teamB]
    won_last[teamA] = row['Awon']
    won_last[teamB] = row['Bwon']
   
results
# Out:
#          date teamA teamB  scoreA  scoreB           fullTeamA  \
# 0  2019-10-02    CG   UOL       0       1       Clutch Gaming
# 1  2019-10-02   DFM   SPY       0       1  DetonatioN FocusMe
# 2  2019-10-02   MMM   UOL       1       0             MAMMOTH
# 3  2019-10-02   DFM   ISG       0       1  DetonatioN FocusMe
# 4  2019-10-02   MMM    CG       0       1             MAMMOTH
# ..        ...   ...   ...     ...     ...                 ...
# 83 2019-10-27   SKT   SPY       3       1       SK Telecom T1
# 84 2019-10-27   DWG    G2       1       3       DAMWON Gaming
# 85 2019-11-02    IG   FPX       1       3     Invictus Gaming
# 86 2019-11-03    G2   SKT       3       1          G2 Esports
# 87 2019-11-10    G2   FPX       0       3          G2 Esports
#
#                fullTeamB   Awon   Bwon regionA  ... BisLCK  BisLCS  BisLPL  \
# 0   Unicorns Of Love.CIS  False   True     LCS  ...  False   False   False
# 1                 Splyce  False   True    None  ...  False   False   False
# 2   Unicorns Of Love.CIS   True  False    None  ...  False   False   False
# 3                 Isurus  False   True    None  ...  False   False   False
# 4          Clutch Gaming  False   True    None  ...  False    True   False
# ..                   ...    ...    ...     ...  ...    ...     ...     ...
# 83                Splyce   True  False     LCK  ...  False   False   False
# 84            G2 Esports  False   True     LCK  ...  False   False   False
# 85       FunPlus Phoenix  False   True     LPL  ...  False   False    True
# 86         SK Telecom T1   True  False     LEC  ...   True   False   False
# 87       FunPlus Phoenix  False   True     LEC  ...  False   False    True
#
#     BisLMS  rankA  rankB  Ahigh  Bhigh  Alastwon  Blastwon
# 0    False      3      5   True  False     False     False
# 1    False      5      3  False   True     False     False
# 2    False      5      5  False  False     False      True
# 3    False      5      5  False  False     False     False
# 4    False      5      3  False   True      True     False
# ..     ...    ...    ...    ...    ...       ...       ...
# 83   False      1      3   True  False      True      True
# 84   False      3      1  False   True      True      True
# 85   False      3      1  False   True      True      True
# 86   False      1      1  False  False      True      True
# 87   False      1      1  False  False      True      True
#
# [88 rows x 25 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
X_previouswins = results[['AisLCK','AisLCS','AisLPL','AisLMS','BisLCK','BisLCS','BisLPL','BisLMS','Ahigh','Bhigh']].values
X_previouswins = results[['AisLCK','AisLCS','AisLPL','AisLMS','BisLCK','BisLCS','BisLPL','BisLMS','rankA','rankB']].values
X_previouswins = results[['AisLCK','AisLCS','AisLPL','AisLMS','BisLCK','BisLCS','BisLPL','BisLMS','rankA','rankB','Alastwon','Blastwon']].values
y_true = results[['Awon','Bwon']].values
clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf, X_previouswins, y_true, scoring='accuracy')
print('score: {:.2f}%'.format(np.mean(scores)*100))
# Out:
# score: 61.18%
