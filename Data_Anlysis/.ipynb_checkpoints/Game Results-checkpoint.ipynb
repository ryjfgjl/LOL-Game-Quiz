# %%
import pymysql
conn = pymysql.connect(host='localhost',port=3306,db='lolgamequiz',user='root',passwd='root',charset='utf8')
def sele(sql):
    cur = conn.cursor()
    cur.execute(sql)
    result = list(cur.fetchall())
    result = [list(r) for r in result]
    conn.commit()
    cur.close()
    
    return result

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
sql = 'select date,processor, dayNum, dayOrder, teamA, teamB, scoreA, scoreB, fullTeamA, fullTeamB from world2019\
 UNION ALL select date,processor, dayNum, dayOrder, teamA, teamB, scoreA, scoreB, fullTeamA, fullTeamB from world2020'
data = sele(sql)
results = pd.DataFrame(data, columns=['date', 'processor','dayNum','dayOrder', 'teamA', 'teamB', 'scoreA', 'scoreB', 'fullTeamA', 'fullTeamB'])
print(results)

sql = 'select teamName, rank, region from rank2019 where region <> "Play-In"\
 UNION ALL select teamName, rank, region from rank2020 where region <> "Play-In"'
data = sele(sql)
rank2019 = pd.DataFrame(data, columns=['teamName', 'rank', 'region'])
print(rank2019)
# Out:
#            date   processor         dayNum dayOrder teamA teamB scoreA scoreB  \
# 0    2019-10-02     Play-In          Day 1        1    CG   UOL      0      1
# 1    2019-10-02     Play-In          Day 1        2   DFM   SPY      0      1
# 2    2019-10-02     Play-In          Day 1        3   MMM   UOL      1      0
# 3    2019-10-12  Main_Event          Day 1        1   FNC   SKT      0      1
# 4    2019-10-02     Play-In          Day 1        4   DFM   ISG      0      1
# 5    2019-10-02     Play-In          Day 1        5   MMM    CG      0      1
# 6    2019-10-02     Play-In          Day 1        6   SPY   ISG      1      0
# 7    2019-10-12  Main_Event          Day 1        2   RNG    CG      1      0
# 8    2019-10-12  Main_Event          Day 1        3    iG   ahq      1      0
# 9    2019-10-03     Play-In          Day 2        1   RYL   DWG      0      1
# 10   2019-10-03     Play-In          Day 2        2  MEGA   HKA      0      1
# 11   2019-10-12  Main_Event          Day 1        4   DWG    TL      0      1
# 12   2019-10-03     Play-In          Day 2        3   DWG   FLA      1      0
# 13   2019-10-03     Play-In          Day 2        4  MEGA    LK      1      0
# 14   2019-10-12  Main_Event          Day 1        5    JT   FPX      1      0
# 15   2019-10-12  Main_Event          Day 1        6   GAM   SPY      0      1
# 16   2019-10-03     Play-In          Day 2        5   RYL   FLA      0      1
# 17   2019-10-03     Play-In          Day 2        6   HKA    LK      0      1
# 18   2019-10-13  Main_Event          Day 2        1   SKT   RNG      1      0
# 19   2019-10-04     Play-In          Day 3        1   UOL    CG      1      0
# 20   2019-10-04     Play-In          Day 3        2   SPY   DFM      0      1
# 21   2019-10-13  Main_Event          Day 2        2   FNC    CG      1      0
# 22   2019-10-13  Main_Event          Day 2        3    TL    iG      0      1
# 23   2019-10-04     Play-In          Day 3        3   UOL   MMM      0      1
# 24   2019-10-04     Play-In          Day 3        4   ISG   DFM      1      0
# 25   2019-10-13  Main_Event          Day 2        4   ahq   DWG      0      1
# 26   2019-10-13  Main_Event          Day 2        5   GRF    G2      0      1
# 27   2019-10-04     Play-In          Day 3        5    CG   MMM      1      0
# 14                  J Team         FunPlus Phoenix
# 15             GAM Esports                  Splyce
# 16             Royal Youth        Flamengo eSports
# 17      Hong Kong Attitude  Lowkey Esports.Vietnam
# 18           SK Telecom T1     Royal Never Give Up
# 19    Unicorns Of Love.CIS           Clutch Gaming
# 20                  Splyce      DetonatioN FocusMe
# 21                  Fnatic           Clutch Gaming
# 22             Team Liquid         Invictus Gaming
# 23    Unicorns Of Love.CIS                 MAMMOTH
# 24                  Isurus      DetonatioN FocusMe
# 25        ahq eSports Club           DAMWON Gaming
# 26                 Griffin              G2 Esports
# 27           Clutch Gaming                 MAMMOTH
# 28                  Cloud9      Hong Kong Attitude
# 29         Invictus Gaming           DAMWON Gaming
# ..                     ...                     ...
# 139           Team SoloMid              LGD Gaming
# 140            Team Liquid              G2 Esports
# 141          Machi Esports                  Suning
# 142             G2 Esports           Machi Esports
# 143                 Suning             Team Liquid
# 144            Team Liquid           Machi Esports
# 145                 Suning              G2 Esports
# 146              PSG Talon           DAMWON Gaming
# 147  Rogue (European Team)               JD Gaming
# 148          DAMWON Gaming   Rogue (European Team)
# 149              JD Gaming               PSG Talon
# 150              PSG Talon   Rogue (European Team)
# 151              JD Gaming           DAMWON Gaming
# 152                 Fnatic            Team SoloMid
# 153             LGD Gaming                   Gen.G
# 154           Team SoloMid                   Gen.G
# 155                 Fnatic              LGD Gaming
# 156             LGD Gaming            Team SoloMid
# 157                  Gen.G                  Fnatic
# 158               FlyQuest                     DRX
# 159   Unicorns Of Love.CIS             Top Esports
# 160                    DRX    Unicorns Of Love.CIS
# 161            Top Esports                FlyQuest
# 162   Unicorns Of Love.CIS                FlyQuest
# 163                    DRX             Top Esports
# 164             G2 Esports                  Suning
# 165          DAMWON Gaming                     DRX
# 166                 Suning               JD Gaming
# 167            Top Esports                  Fnatic
# 168                  Gen.G              G2 Esports
#
# [169 rows x 10 columns]
#                   teamName rank region
# 0          FunPlus Phoenix    1     CN
# 1               G2 Esports    1     EU
# 2            SK Telecom T1    1     KR
# 3              Team Liquid    1     NA
# 4         Ahq eSports Club    2    LMS
# 5                   Cloud9    2     NA
# 6                   Fnatic    2     EU
# 7              GAM Esports    1     VN
# 8                  Griffin    2     KR
# 9            Clutch Gaming    3     NA
# 10         Invictus Gaming    3     CN
# 11           DAMWON Gaming    3     KR
# 12                  J Team    1    LMS
# 13     Royal Never Give Up    2     CN
# 14      Hong Kong Attitude    3    LMS
# 15                  Splyce    3     EU
# 16           Clutch Gaming    1     NA
# 17                  Isurus    1    LAT
# 18  Lowkey Esports.Vietnam    2     VN
# 19           DAMWON Gaming    1     KR
# 20             Royal Youth    1     TR
# 21    Unicorns Of Love.CIS    1    CIS
# 22      Hong Kong Attitude    1    LMS
# 23                  Splyce    1     EU
# 24      DetonatioN FocusMe    1     JP
# 25        Flamengo eSports    1     BR
# 26                 MAMMOTH    1    OCE
# 27                    MEGA    1    SEA
# 28              LGD Gaming    4     CN
# 29               MAD Lions    4     EU
# 30             Team Liquid    3     NA
# 31               PSG Talon    2    PCS
# 32             Top Esports    1     CN
# 33                    INTZ    1     BR
# 34    Unicorns Of Love.CIS    1    CIS
# 35              G2 Esports    1     EU
# 36              V3 Esports    1     JP
# 37                Rainbow7    1    LAT
# 38           DAMWON Gaming    1     KR
# 39          Legacy Esports    1    OCE
# 40            Team SoloMid    1     NA
# 41               JD Gaming    2     CN
# 42    SuperMassive Esports    1     TR
# 43                  Suning    3     CN
# 44                  Fnatic    2     EU
# 45                     DRX    2     KR
# 46   Rogue (European Team)    3     EU
# 47                   Gen.G    3     KR
# 48                FlyQuest    2     NA
# 49           Machi Esports    1    PCS
# 50              LGD Gaming    1     CN
# 51             Team Liquid    1     NA
# 52               PSG Talon    1    PCS
# 53    Unicorns Of Love.CIS    1    CIS

# %%
# clean data
# cover data type
results = results.astype({'date':'datetime64', 'scoreA':'int64', 'scoreB':'int64'})
# fix team name
results['teamA'] = results['teamA'].apply(lambda x: x.upper())
results['teamB'] = results['teamB'].apply(lambda x: x.upper())
results['fullTeamA'] = results['fullTeamA'].apply(lambda x: x.upper())
results['fullTeamB'] = results['fullTeamB'].apply(lambda x: x.upper())
# sort
results = results.sort_values(by=['date','dayNum','dayOrder'])
results = results.reset_index()
results = results.drop(['index'], axis=1)
print(results)

####################
# rank2019
# rank
rank2019 = rank2019.astype({'rank':'int64'})
rank2019['teamName'] = rank2019['teamName'].apply(lambda x: x.upper())
#results = results.merge(rank2019, how='left', left_on='fullTeamA', right_on='teamName')
#rank2019
print(rank2019)
# Out:
#           date   processor         dayNum dayOrder teamA teamB  scoreA  \
# 0   2019-10-02     Play-In          Day 1        1    CG   UOL       0
# 1   2019-10-02     Play-In          Day 1        2   DFM   SPY       0
# 2   2019-10-02     Play-In          Day 1        3   MMM   UOL       1
# 3   2019-10-02     Play-In          Day 1        4   DFM   ISG       0
# 4   2019-10-02     Play-In          Day 1        5   MMM    CG       0
# 5   2019-10-02     Play-In          Day 1        6   SPY   ISG       1
# 6   2019-10-03     Play-In          Day 2        1   RYL   DWG       0
# 7   2019-10-03     Play-In          Day 2        2  MEGA   HKA       0
# 8   2019-10-03     Play-In          Day 2        3   DWG   FLA       1
# 9   2019-10-03     Play-In          Day 2        4  MEGA    LK       1
# 10  2019-10-03     Play-In          Day 2        5   RYL   FLA       0
# 11  2019-10-03     Play-In          Day 2        6   HKA    LK       0
# 12  2019-10-04     Play-In          Day 3        1   UOL    CG       1
# 13  2019-10-04     Play-In          Day 3        2   SPY   DFM       0
# 14  2019-10-04     Play-In          Day 3        3   UOL   MMM       0
# 15  2019-10-04     Play-In          Day 3        4   ISG   DFM       1
# 16  2019-10-04     Play-In          Day 3        5    CG   MMM       1
# 17  2019-10-04     Play-In          Day 3        6   ISG   SPY       0
# 18  2019-10-04     Play-In    Tiebreakers        1   UOL   MMM       1
# 19  2019-10-04     Play-In    Tiebreakers        2    CG   UOL       1
# 20  2019-10-05     Play-In          Day 4        1   DWG   RYL       1
# 21  2019-10-05     Play-In          Day 4        2   HKA  MEGA       1
# 7         1                    MEGA      HONG KONG ATTITUDE
# 8         0           DAMWON GAMING        FLAMENGO ESPORTS
# 9         0                    MEGA  LOWKEY ESPORTS.VIETNAM
# 10        1             ROYAL YOUTH        FLAMENGO ESPORTS
# 11        1      HONG KONG ATTITUDE  LOWKEY ESPORTS.VIETNAM
# 12        0    UNICORNS OF LOVE.CIS           CLUTCH GAMING
# 13        1                  SPLYCE      DETONATION FOCUSME
# 14        1    UNICORNS OF LOVE.CIS                 MAMMOTH
# 15        0                  ISURUS      DETONATION FOCUSME
# 16        0           CLUTCH GAMING                 MAMMOTH
# 17        1                  ISURUS                  SPLYCE
# 18        0    UNICORNS OF LOVE.CIS                 MAMMOTH
# 19        0           CLUTCH GAMING    UNICORNS OF LOVE.CIS
# 20        0           DAMWON GAMING             ROYAL YOUTH
# 21        0      HONG KONG ATTITUDE                    MEGA
# 22        1        FLAMENGO ESPORTS           DAMWON GAMING
# 23        0  LOWKEY ESPORTS.VIETNAM                    MEGA
# 24        1        FLAMENGO ESPORTS             ROYAL YOUTH
# 25        1  LOWKEY ESPORTS.VIETNAM      HONG KONG ATTITUDE
# 26        1        FLAMENGO ESPORTS             ROYAL YOUTH
# 27        1           DAMWON GAMING  LOWKEY ESPORTS.VIETNAM
# 28        0           CLUTCH GAMING             ROYAL YOUTH
# 29        1      HONG KONG ATTITUDE                  ISURUS
# ..      ...                     ...                     ...
# 139       1            TEAM SOLOMID              LGD GAMING
# 140       1             TEAM LIQUID              G2 ESPORTS
# 141       1           MACHI ESPORTS                  SUNING
# 142       0              G2 ESPORTS           MACHI ESPORTS
# 143       1                  SUNING             TEAM LIQUID
# 144       0             TEAM LIQUID           MACHI ESPORTS
# 145       0                  SUNING              G2 ESPORTS
# 146       1              G2 ESPORTS                  SUNING
# 147       1               PSG TALON           DAMWON GAMING
# 148       1   ROGUE (EUROPEAN TEAM)               JD GAMING
# 149       0           DAMWON GAMING   ROGUE (EUROPEAN TEAM)
# 150       1               JD GAMING               PSG TALON
# 151       0               PSG TALON   ROGUE (EUROPEAN TEAM)
# 152       0               JD GAMING           DAMWON GAMING
# 153       0                  FNATIC            TEAM SOLOMID
# 154       1              LGD GAMING                   GEN.G
# 155       1            TEAM SOLOMID                   GEN.G
# 156       0                  FNATIC              LGD GAMING
# 157       0              LGD GAMING            TEAM SOLOMID
# 158       0                   GEN.G                  FNATIC
# 159       1                FLYQUEST                     DRX
# 160       1    UNICORNS OF LOVE.CIS             TOP ESPORTS
# 161       0                     DRX    UNICORNS OF LOVE.CIS
# 162       1             TOP ESPORTS                FLYQUEST
# 163       1    UNICORNS OF LOVE.CIS                FLYQUEST
# 164       1                     DRX             TOP ESPORTS
# 165       0           DAMWON GAMING                     DRX
# 166       0                  SUNING               JD GAMING
# 167       0             TOP ESPORTS                  FNATIC
# 168       0                   GEN.G              G2 ESPORTS
#
# [169 rows x 10 columns]
#                   teamName  rank region
# 0          FUNPLUS PHOENIX     1     CN
# 1               G2 ESPORTS     1     EU
# 2            SK TELECOM T1     1     KR
# 3              TEAM LIQUID     1     NA
# 4         AHQ ESPORTS CLUB     2    LMS
# 5                   CLOUD9     2     NA
# 6                   FNATIC     2     EU
# 7              GAM ESPORTS     1     VN
# 8                  GRIFFIN     2     KR
# 9            CLUTCH GAMING     3     NA
# 10         INVICTUS GAMING     3     CN
# 11           DAMWON GAMING     3     KR
# 12                  J TEAM     1    LMS
# 13     ROYAL NEVER GIVE UP     2     CN
# 14      HONG KONG ATTITUDE     3    LMS
# 15                  SPLYCE     3     EU
# 16           CLUTCH GAMING     1     NA
# 17                  ISURUS     1    LAT
# 18  LOWKEY ESPORTS.VIETNAM     2     VN
# 19           DAMWON GAMING     1     KR
# 20             ROYAL YOUTH     1     TR
# 21    UNICORNS OF LOVE.CIS     1    CIS
# 22      HONG KONG ATTITUDE     1    LMS
# 23                  SPLYCE     1     EU
# 24      DETONATION FOCUSME     1     JP
# 25        FLAMENGO ESPORTS     1     BR
# 26                 MAMMOTH     1    OCE
# 27                    MEGA     1    SEA
# 28              LGD GAMING     4     CN
# 29               MAD LIONS     4     EU
# 30             TEAM LIQUID     3     NA
# 31               PSG TALON     2    PCS
# 32             TOP ESPORTS     1     CN
# 33                    INTZ     1     BR
# 34    UNICORNS OF LOVE.CIS     1    CIS
# 35              G2 ESPORTS     1     EU
# 36              V3 ESPORTS     1     JP
# 37                RAINBOW7     1    LAT
# 38           DAMWON GAMING     1     KR
# 39          LEGACY ESPORTS     1    OCE
# 40            TEAM SOLOMID     1     NA
# 41               JD GAMING     2     CN
# 42    SUPERMASSIVE ESPORTS     1     TR
# 43                  SUNING     3     CN
# 44                  FNATIC     2     EU
# 45                     DRX     2     KR
# 46   ROGUE (EUROPEAN TEAM)     3     EU
# 47                   GEN.G     3     KR
# 48                FLYQUEST     2     NA
# 49           MACHI ESPORTS     1    PCS
# 50              LGD GAMING     1     CN
# 51             TEAM LIQUID     1     NA
# 52               PSG TALON     1    PCS
# 53    UNICORNS OF LOVE.CIS     1    CIS

# %%
gy = rank2019['region'].groupby(rank2019['region'])
print(gy.count())
# Out:
# region
# BR     2
# CIS    3
# CN     8
# EU     8
# JP     2
# KR     7
# LAT    2
# LMS    4
# NA     8
# OCE    2
# PCS    3
# SEA    1
# TR     2
# VN     2
# Name: region, dtype: int64

# %%
# won
results['Awon'] = False
results['Bwon'] = False
results['Awon'] = results['scoreA']>results['scoreB']
results['Bwon'] = results['scoreA']<results['scoreB']
results
# Out:
#           date   processor         dayNum dayOrder teamA teamB  scoreA  \
# 0   2019-10-02     Play-In          Day 1        1    CG   UOL       0
# 1   2019-10-02     Play-In          Day 1        2   DFM   SPY       0
# 2   2019-10-02     Play-In          Day 1        3   MMM   UOL       1
# 3   2019-10-02     Play-In          Day 1        4   DFM   ISG       0
# 4   2019-10-02     Play-In          Day 1        5   MMM    CG       0
# 5   2019-10-02     Play-In          Day 1        6   SPY   ISG       1
# 6   2019-10-03     Play-In          Day 2        1   RYL   DWG       0
# 161 2020-10-11  Main_Event          Day 8        3   DRX   UOL       1
# 162 2020-10-11  Main_Event          Day 8        4   TES   FLY       0
# 163 2020-10-11  Main_Event          Day 8        5   UOL   FLY       0
# 164 2020-10-11  Main_Event          Day 8        6   DRX   TES       0
# 165 2020-10-15  Main_Event  Quarterfinals        4   DWG   DRX       0
# 166 2020-10-16  Main_Event  Quarterfinals        2    SN   JDG       0
# 167 2020-10-17  Main_Event  Quarterfinals        1   TES   FNC       0
# 168 2020-10-18  Main_Event  Quarterfinals        3   GEN    G2       0
#
#      scoreB               fullTeamA               fullTeamB   Awon   Bwon
# 0         1           CLUTCH GAMING    UNICORNS OF LOVE.CIS  False   True
# 1         1      DETONATION FOCUSME                  SPLYCE  False   True
# 2         0                 MAMMOTH    UNICORNS OF LOVE.CIS   True  False
# 3         1      DETONATION FOCUSME                  ISURUS  False   True
# 4         1                 MAMMOTH           CLUTCH GAMING  False   True
# 5         0                  SPLYCE                  ISURUS   True  False
# 6         1             ROYAL YOUTH           DAMWON GAMING  False   True
# 7         1                    MEGA      HONG KONG ATTITUDE  False   True
# 8         0           DAMWON GAMING        FLAMENGO ESPORTS   True  False
# 9         0                    MEGA  LOWKEY ESPORTS.VIETNAM   True  False
# 10        1             ROYAL YOUTH        FLAMENGO ESPORTS  False   True
# 11        1      HONG KONG ATTITUDE  LOWKEY ESPORTS.VIETNAM  False   True
# 12        0    UNICORNS OF LOVE.CIS           CLUTCH GAMING   True  False
# 13        1                  SPLYCE      DETONATION FOCUSME  False   True
# 14        1    UNICORNS OF LOVE.CIS                 MAMMOTH  False   True
# 15        0                  ISURUS      DETONATION FOCUSME   True  False
# 16        0           CLUTCH GAMING                 MAMMOTH   True  False
# 17        1                  ISURUS                  SPLYCE  False   True
# 18        0    UNICORNS OF LOVE.CIS                 MAMMOTH   True  False
# 19        0           CLUTCH GAMING    UNICORNS OF LOVE.CIS   True  False
# 20        0           DAMWON GAMING             ROYAL YOUTH   True  False
# 21        0      HONG KONG ATTITUDE                    MEGA   True  False
# 22        1        FLAMENGO ESPORTS           DAMWON GAMING  False   True
# 23        0  LOWKEY ESPORTS.VIETNAM                    MEGA   True  False
# 24        1        FLAMENGO ESPORTS             ROYAL YOUTH  False   True
# 25        1  LOWKEY ESPORTS.VIETNAM      HONG KONG ATTITUDE  False   True
# 26        1        FLAMENGO ESPORTS             ROYAL YOUTH  False   True
# 27        1           DAMWON GAMING  LOWKEY ESPORTS.VIETNAM   True  False
# 28        0           CLUTCH GAMING             ROYAL YOUTH   True  False
# 29        1      HONG KONG ATTITUDE                  ISURUS   True  False
# ..      ...                     ...                     ...    ...    ...
# 139       1            TEAM SOLOMID              LGD GAMING  False   True
# 140       1             TEAM LIQUID              G2 ESPORTS  False   True
# 141       1           MACHI ESPORTS                  SUNING  False   True
# 142       0              G2 ESPORTS           MACHI ESPORTS   True  False
# 143       1                  SUNING             TEAM LIQUID  False   True
# 144       0             TEAM LIQUID           MACHI ESPORTS   True  False
# 145       0                  SUNING              G2 ESPORTS   True  False
# 146       1              G2 ESPORTS                  SUNING  False   True
# 147       1               PSG TALON           DAMWON GAMING  False   True
# 148       1   ROGUE (EUROPEAN TEAM)               JD GAMING  False   True
# 149       0           DAMWON GAMING   ROGUE (EUROPEAN TEAM)   True  False
# 150       1               JD GAMING               PSG TALON  False   True
# 151       0               PSG TALON   ROGUE (EUROPEAN TEAM)   True  False
# 152       0               JD GAMING           DAMWON GAMING   True  False
# 153       0                  FNATIC            TEAM SOLOMID   True  False
# 154       1              LGD GAMING                   GEN.G  False   True
# 155       1            TEAM SOLOMID                   GEN.G  False   True
# 156       0                  FNATIC              LGD GAMING   True  False
# 157       0              LGD GAMING            TEAM SOLOMID   True  False
# 158       0                   GEN.G                  FNATIC   True  False
# 159       1                FLYQUEST                     DRX  False   True
# 160       1    UNICORNS OF LOVE.CIS             TOP ESPORTS  False   True
# 161       0                     DRX    UNICORNS OF LOVE.CIS   True  False
# 162       1             TOP ESPORTS                FLYQUEST  False   True
# 163       1    UNICORNS OF LOVE.CIS                FLYQUEST  False   True
# 164       1                     DRX             TOP ESPORTS  False   True
# 165       0           DAMWON GAMING                     DRX  False  False
# 166       0                  SUNING               JD GAMING  False  False
# 167       0             TOP ESPORTS                  FNATIC  False  False
# 168       0                   GEN.G              G2 ESPORTS  False  False
#
# [169 rows x 12 columns]

# %%
############################################
# region
results['regionA'] = ''
results['regionB'] = ''

results['AisBR'] = False
results['AisCIS'] = False
results['AisCN'] = False
results['AisEU'] = False
results['AisJP'] = False
results['AisKR'] = False
results['AisLAT'] = False
results['AisLMS'] = False
results['AisNA'] = False
results['AisOCE'] = False
results['AisSEA'] = False
results['AisTR'] = False
results['AisVN'] = False

results['BisBR'] = False
results['BisCIS'] = False
results['BisCN'] = False
results['BisEU'] = False
results['BisJP'] = False
results['BisKR'] = False
results['BisLAT'] = False
results['BisLMS'] = False
results['BisNA'] = False
results['BisOCE'] = False
results['BisSEA'] = False
results['BisTR'] = False
results['BisVN'] = False

for index, row in results.iterrows():
    teamA = row['fullTeamA']
    teamB = row['fullTeamB']
    regionA = rank2019[rank2019['teamName']==teamA]
    if not regionA.empty:
        regionA = regionA['region'].values[0]
        results.loc[index,'regionA'] = regionA
        if regionA == 'BR':
            results.loc[index,'AisBR'] = True
        elif regionA == 'CIS':
            results.loc[index,'AisCIS'] = True
        elif regionA == 'CN':
            results.loc[index,'AisCN'] = True
        elif regionA == 'EU':
            results.loc[index,'AisEU'] = True
        elif regionA == 'JP':
            results.loc[index,'AisJP'] = True
        elif regionA == 'KR':
            results.loc[index,'AisKR'] = True
        elif regionA == 'LAT':
            results.loc[index,'AisLAT'] = True
        elif regionA == 'LMS':
            results.loc[index,'AisLMS'] = True
        elif regionA == 'NA':
            results.loc[index,'AisNA'] = True
        elif regionA == 'OCE':
            results.loc[index,'AisOCE'] = True
        elif regionA == 'SEA':
            results.loc[index,'AisSEA'] = True
        elif regionA == 'TR':
            results.loc[index,'AisTR'] = True
        elif regionA == 'VN':
            results.loc[index,'AisVN'] = True
        
    regionB = rank2019[rank2019['teamName']==teamB]
    if not regionB.empty:
        regionB = regionB['region'].values[0]
        results.loc[index,'regionB'] = regionB
        if regionB == 'BR':
            results.loc[index,'BisBR'] = True
        elif regionB == 'CIS':
            results.loc[index,'BisCIS'] = True
        elif regionB == 'CN':
            results.loc[index,'BisCN'] = True
        elif regionB == 'EU':
            results.loc[index,'BisEU'] = True
        elif regionB == 'JP':
            results.loc[index,'BisJP'] = True
        elif regionB == 'KR':
            results.loc[index,'BisKR'] = True
        elif regionB == 'LAT':
            results.loc[index,'BisLAT'] = True
        elif regionB == 'LMS':
            results.loc[index,'BisLMS'] = True
        elif regionB == 'NA':
            results.loc[index,'BisNA'] = True
        elif regionB == 'OCE':
            results.loc[index,'BisOCE'] = True
        elif regionB == 'SEA':
            results.loc[index,'BisSEA'] = True
        elif regionB == 'TR':
            results.loc[index,'BisTR'] = True
        elif regionB == 'VN':
            results.loc[index,'BisVN'] = True
"""
############################################
# rank
results['rankA'] = 5
results['rankB'] = 5
results['Ahigh'] = False
results['Bhigh'] = False
for index, row in results.iterrows():
    teamA = row['fullTeamA']
    teamB = row['fullTeamB']
    rankA = rank2019[rank2019['teamName']==teamA]
    if not rankA.empty:
        rankA = rankA['rank'].values[0]
    else:
        rankA = 5

    rankB = rank2019[rank2019['teamName']==teamB]
    if not rankB.empty:
        rankB = rankB['rank'].values[0]
    else:
        rankB = 5
    
    if rankA < rankB:
        results.loc[index,'Ahigh'] = True
    if rankB < rankA:
        results.loc[index,'Bhigh'] = True
        
    results.loc[index,'rankA'] = rankA
    results.loc[index,'rankB'] = rankB
    

##################################
# last won
results['Alastwon'] = False
results['Blastwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        won_last[teamA] = row['Awon']
        won_last[teamB] = row['Bwon']
        continue

    results.loc[index, 'Alastwon'] = won_last[teamA]
    results.loc[index, 'Blastwon'] = won_last[teamB]
    won_last[teamA] = row['Awon']
    won_last[teamB] = row['Bwon']

##################################
# last who won
results['lastAwon'] = False
results['lastBwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        continue
    for index1, row1 in results[:index].iterrows():
        if row1['teamA'] == teamA and row1['teamB'] == teamB:
            results.loc[index, 'lastAwon'] = results.loc[index1, 'Awon']
            results.loc[index, 'lastBwon'] = results.loc[index1, 'Bwon']
        elif row1['teamA'] == teamB and row1['teamB'] == teamA:
            results.loc[index, 'lastAwon'] = results.loc[index1, 'Bwon']
            results.loc[index, 'lastBwon'] = results.loc[index1, 'Awon']

##################################
# BO
def bo(score, win_num):
    max_score = max(score['scoreA'], score['scoreB'])
    if max_score == win_num:
        return True
    else:
        return False
        
results['isBo1'] = results[['scoreA','scoreB']].apply(bo, args=(1,), axis=1)
results['isBo5'] = results[['scoreA','scoreB']].apply(bo, args=(3,), axis=1)

results
"""
# Out:
# "\n############################################\n# rank\nresults['rankA'] = 5\nresults['rankB'] = 5\nresults['Ahigh'] = False\nresults['Bhigh'] = False\nfor index, row in results.iterrows():\n    teamA = row['fullTeamA']\n    teamB = row['fullTeamB']\n    rankA = rank2019[rank2019['teamName']==teamA]\n    if not rankA.empty:\n        rankA = rankA['rank'].values[0]\n    else:\n        rankA = 5\n\n    rankB = rank2019[rank2019['teamName']==teamB]\n    if not rankB.empty:\n        rankB = rankB['rank'].values[0]\n    else:\n        rankB = 5\n    \n    if rankA < rankB:\n        results.loc[index,'Ahigh'] = True\n    if rankB < rankA:\n        results.loc[index,'Bhigh'] = True\n        \n    results.loc[index,'rankA'] = rankA\n    results.loc[index,'rankB'] = rankB\n    \n\n##################################\n# last won\nresults['Alastwon'] = False\nresults['Blastwon'] = False\nwon_last = defaultdict(bool)\nfor index, row in results.iterrows():\n    teamA = row['teamA']\n    teamB = row['teamB']\n    if index == 0:\n        won_last[teamA] = row['Awon']\n        won_last[teamB] = row['Bwon']\n        continue\n\n    results.loc[index, 'Alastwon'] = won_last[teamA]\n    results.loc[index, 'Blastwon'] = won_last[teamB]\n    won_last[teamA] = row['Awon']\n    won_last[teamB] = row['Bwon']\n\n##################################\n# last who won\nresults['lastAwon'] = False\nresults['lastBwon'] = False\nwon_last = defaultdict(bool)\nfor index, row in results.iterrows():\n    teamA = row['teamA']\n    teamB = row['teamB']\n    if index == 0:\n        continue\n    for index1, row1 in results[:index].iterrows():\n        if row1['teamA'] == teamA and row1['teamB'] == teamB:\n            results.loc[index, 'lastAwon'] = results.loc[index1, 'Awon']\n            results.loc[index, 'lastBwon'] = results.loc[index1, 'Bwon']\n        elif row1['teamA'] == teamB and row1['teamB'] == teamA:\n            results.loc[index, 'lastAwon'] = results.loc[index1, 'Bwon']\n            results.loc[index, 'lastBwon'] = results.loc[index1, 'Awon']\n\n##################################\n# BO\ndef bo(score, win_num):\n    max_score = max(score['scoreA'], score['scoreB'])\n    if max_score == win_num:\n        return True\n    else:\n        return False\n        \nresults['isBo1'] = results[['scoreA','scoreB']].apply(bo, args=(1,), axis=1)\nresults['isBo5'] = results[['scoreA','scoreB']].apply(bo, args=(3,), axis=1)\n\nresults\n"

# %%
############################################
# region/rank
#results['regionA'] = ''
#results['regionB'] = ''
results['rankA'] = ''
results['rankB'] = ''

for index, row in results.iterrows():
    teamA = row['fullTeamA']
    teamB = row['fullTeamB']
    regionA = rank2019.loc[rank2019[rank2019['teamName']==teamA].index,'region']
    regionB = rank2019.loc[rank2019[rank2019['teamName']==teamB].index,'region']
    
    rankA = rank2019.loc[rank2019[rank2019['teamName']==teamA].index,'rank']
    rankB = rank2019.loc[rank2019[rank2019['teamName']==teamB].index,'rank']
    
    if not regionA.empty:
        #results.loc[index, 'regionA'] = regionA.values[0]
        results.loc[index, 'rankA'] = rankA.values[0]
    if not regionB.empty:
        #results.loc[index, 'regionB'] = regionB.values[0]
        results.loc[index, 'rankB'] = rankB.values[0]

##################################
# last won
results['Alastwon'] = False
results['Blastwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        won_last[teamA] = row['Awon']
        won_last[teamB] = row['Bwon']
        continue

    results.loc[index, 'Alastwon'] = won_last[teamA]
    results.loc[index, 'Blastwon'] = won_last[teamB]
    won_last[teamA] = row['Awon']
    won_last[teamB] = row['Bwon']

##################################
# last who won
results['lastAwon'] = False
results['lastBwon'] = False
won_last = defaultdict(bool)
for index, row in results.iterrows():
    teamA = row['teamA']
    teamB = row['teamB']
    if index == 0:
        continue
    for index1, row1 in results[:index].iterrows():
        if row1['teamA'] == teamA and row1['teamB'] == teamB:
            results.loc[index, 'lastAwon'] = results.loc[index1, 'Awon']
            results.loc[index, 'lastBwon'] = results.loc[index1, 'Bwon']
        elif row1['teamA'] == teamB and row1['teamB'] == teamA:
            results.loc[index, 'lastAwon'] = results.loc[index1, 'Bwon']
            results.loc[index, 'lastBwon'] = results.loc[index1, 'Awon']

##################################
# BO
def bo(score):
    max_score = max(score['scoreA'], score['scoreB'])
    if max_score == 1:
        return True
    elif max_score == 3:
        return False
        
results['BO1'] = results[['scoreA','scoreB']].apply(bo, axis=1)


##################################
# isGroup
from datetime import datetime     
results['isGroup'] = results['date'].apply(lambda x:True if x <= datetime.strptime('2019-10-20','%Y-%m-%d') else False)
results
# Out:
#           date   processor         dayNum dayOrder teamA teamB  scoreA  \
# 0   2019-10-02     Play-In          Day 1        1    CG   UOL       0
# 1   2019-10-02     Play-In          Day 1        2   DFM   SPY       0
# 2   2019-10-02     Play-In          Day 1        3   MMM   UOL       1
# 3   2019-10-02     Play-In          Day 1        4   DFM   ISG       0
# 4   2019-10-02     Play-In          Day 1        5   MMM    CG       0
# 5   2019-10-02     Play-In          Day 1        6   SPY   ISG       1
# 6   2019-10-03     Play-In          Day 2        1   RYL   DWG       0
# 7   2019-10-03     Play-In          Day 2        2  MEGA   HKA       0
# 8   2019-10-03     Play-In          Day 2        3   DWG   FLA       1
# 9   2019-10-03     Play-In          Day 2        4  MEGA    LK       1
# 10  2019-10-03     Play-In          Day 2        5   RYL   FLA       0
# 11  2019-10-03     Play-In          Day 2        6   HKA    LK       0
# 12  2019-10-04     Play-In          Day 3        1   UOL    CG       1
# 13  2019-10-04     Play-In          Day 3        2   SPY   DFM       0
# 14  2019-10-04     Play-In          Day 3        3   UOL   MMM       0
# 15  2019-10-04     Play-In          Day 3        4   ISG   DFM       1
# 16  2019-10-04     Play-In          Day 3        5    CG   MMM       1
# 17  2019-10-04     Play-In          Day 3        6   ISG   SPY       0
# 18  2019-10-04     Play-In    Tiebreakers        1   UOL   MMM       1
# 19  2019-10-04     Play-In    Tiebreakers        2    CG   UOL       1
# 20  2019-10-05     Play-In          Day 4        1   DWG   RYL       1
# 21  2019-10-05     Play-In          Day 4        2   HKA  MEGA       1
# 22  2019-10-05     Play-In          Day 4        3   FLA   DWG       0
# 6         1             ROYAL YOUTH           DAMWON GAMING   ...     False
# 7         1                    MEGA      HONG KONG ATTITUDE   ...     False
# 8         0           DAMWON GAMING        FLAMENGO ESPORTS   ...     False
# 9         0                    MEGA  LOWKEY ESPORTS.VIETNAM   ...     False
# 10        1             ROYAL YOUTH        FLAMENGO ESPORTS   ...     False
# 11        1      HONG KONG ATTITUDE  LOWKEY ESPORTS.VIETNAM   ...     False
# 12        0    UNICORNS OF LOVE.CIS           CLUTCH GAMING   ...     False
# 13        1                  SPLYCE      DETONATION FOCUSME   ...     False
# 14        1    UNICORNS OF LOVE.CIS                 MAMMOTH   ...     False
# 15        0                  ISURUS      DETONATION FOCUSME   ...     False
# 16        0           CLUTCH GAMING                 MAMMOTH   ...     False
# 17        1                  ISURUS                  SPLYCE   ...     False
# 18        0    UNICORNS OF LOVE.CIS                 MAMMOTH   ...     False
# 19        0           CLUTCH GAMING    UNICORNS OF LOVE.CIS   ...     False
# 20        0           DAMWON GAMING             ROYAL YOUTH   ...      True
# 21        0      HONG KONG ATTITUDE                    MEGA   ...     False
# 22        1        FLAMENGO ESPORTS           DAMWON GAMING   ...     False
# 23        0  LOWKEY ESPORTS.VIETNAM                    MEGA   ...     False
# 24        1        FLAMENGO ESPORTS             ROYAL YOUTH   ...      True
# 25        1  LOWKEY ESPORTS.VIETNAM      HONG KONG ATTITUDE   ...     False
# 26        1        FLAMENGO ESPORTS             ROYAL YOUTH   ...      True
# 27        1           DAMWON GAMING  LOWKEY ESPORTS.VIETNAM   ...     False
# 28        0           CLUTCH GAMING             ROYAL YOUTH   ...      True
# 29        1      HONG KONG ATTITUDE                  ISURUS   ...     False
# ..      ...                     ...                     ...   ...       ...
# 139       1            TEAM SOLOMID              LGD GAMING   ...     False
# 140       1             TEAM LIQUID              G2 ESPORTS   ...     False
# 141       1           MACHI ESPORTS                  SUNING   ...     False
# 142       0              G2 ESPORTS           MACHI ESPORTS   ...     False
# 143       1                  SUNING             TEAM LIQUID   ...     False
# 144       0             TEAM LIQUID           MACHI ESPORTS   ...     False
# 145       0                  SUNING              G2 ESPORTS   ...     False
# 146       1              G2 ESPORTS                  SUNING   ...     False
# 147       1               PSG TALON           DAMWON GAMING   ...     False
# 148       1   ROGUE (EUROPEAN TEAM)               JD GAMING   ...     False
# 149       0           DAMWON GAMING   ROGUE (EUROPEAN TEAM)   ...     False
# 150       1               JD GAMING               PSG TALON   ...     False
# 151       0               PSG TALON   ROGUE (EUROPEAN TEAM)   ...     False
# 152       0               JD GAMING           DAMWON GAMING   ...     False
# 153       0                  FNATIC            TEAM SOLOMID   ...     False
# 154       1              LGD GAMING                   GEN.G   ...     False
# 155       1            TEAM SOLOMID                   GEN.G   ...     False
# 156       0                  FNATIC              LGD GAMING   ...     False
# 157       0              LGD GAMING            TEAM SOLOMID   ...     False
# 158       0                   GEN.G                  FNATIC   ...     False
# 159       1                FLYQUEST                     DRX   ...     False
# 160       1    UNICORNS OF LOVE.CIS             TOP ESPORTS   ...     False
columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
X_previouswins = results.loc[results[(results['scoreA']+results['scoreB']>0) & (results['processor']=='Main_Event')].index,
                             ['AisBR','AisCIS','AisCN','AisEU','AisJP','AisKR','AisLAT','AisLMS','AisNA','AisOCE','AisSEA','AisTR','AisVN',      
                          'BisBR','BisCIS','BisCN','BisEU','BisJP','BisKR','BisLAT','BisLMS','BisNA','BisOCE','BisSEA','BisTR','BisVN'
                          ]].values
y_true = results.loc[results[(results['scoreA']+results['scoreB']>0) & (results['processor']=='Main_Event')].index,['Awon']].values

clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf, X_previouswins, y_true, scoring='accuracy')
print('score: {:.2f}%'.format(np.mean(scores)*100))
# Out:
# score: 64.15%

# %%
from sklearn.preprocessing import LabelEncoder
encoding = LabelEncoder()
encoding.fit_transform(results['regionA'].values)
regionA = encoding.fit_transform(results['regionA'].values)
regionB = encoding.fit_transform(results['regionB'].values)

encoding.fit_transform(results['dayNum'].values)
dayNum = encoding.fit_transform(results['dayNum'].values)

region = np.vstack([regionA, regionB,dayNum]).T

from sklearn.preprocessing import OneHotEncoder
onehot = OneHotEncoder()
r = onehot.fit_transform(region).todense()


df = pd.DataFrame(r)

# %%
X_previouswins = results[['rankA','rankB']]
X_previouswins = results[['lastAwon','lastBwon','BO1']]
X_previouswins = results[[]]
#X_previouswins = results[['regionA','regionB','rankA','rankB','lastAwon','lastBwon','Alastwon','Blastwon','BO1']].values

X_previouswins = X_previouswins.join(df)
X_previouswins = X_previouswins.values
clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf, X_previouswins, y_true, scoring='accuracy')
print('score: {:.2f}%'.format(np.mean(scores)*100))
# Out:
# score: 68.24%

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=14)
scores = cross_val_score(clf, X_previouswins, y_true, scoring='accuracy')
print('score: {:.2f}%'.format(np.mean(scores)*100))
# Out:
# score: 65.03%
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
from sklearn.model_selection import GridSearchCV
parameter_space = {
                   "max_features": ['auto'],
                   "n_estimators": [100,],
                   "criterion": ["gini", "entropy"],
                   "min_samples_leaf": [2, 4, 6],
                   }
clf = RandomForestClassifier(random_state=14)
grid = GridSearchCV(clf, parameter_space)
grid.fit(X_previouswins, y_true)
print("Accuracy: {0:.1f}%".format(grid.best_score_ * 100))
print(grid.best_estimator_)
# Out:
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Accuracy: 78.9%
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=14, verbose=0, warm_start=False)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:740: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
forest = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=2, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=14, verbose=0, warm_start=False)

scores = cross_val_score(forest, X_previouswins, y_true, scoring='accuracy')
print('score: {:.2f}%'.format(np.mean(scores)*100))
forest.fit(X_previouswins,y_true)

from sklearn.externals import joblib
joblib.dump(forest, 'forest.m')
# Out:
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/ryjfgjl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# score: 78.90%
# ['forest.m']
